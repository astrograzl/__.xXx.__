# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.style.use("seaborn-darkgrid")
plt.rcParams["figure.figsize"] = (16, 9)
plt.rcParams["image.cmap"] = "Spectral"

# %%
pollux = np.load("pollux.npy")
lamost = np.load("lamost.npy")

# %%
plt.title("Colored uncertainty of functionality")
plt.xlabel("Logaritmus of $T_\mathrm{eff}$")
plt.ylabel("Logaritmus of $g$")
plt.colorbar().ax.set_ylabel("Fe/H");
plt.scatter(lamost[:,0], lamost[:,1], c=lamost[:,2], s=2, alpha=0.5)
plt.scatter(pollux[:,0], pollux[:,1], c=pollux[:,2], s=2, alpha=0.7)
plt.gca().invert_xaxis(); plt.gca().invert_yaxis();
